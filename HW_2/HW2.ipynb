# %% [markdown]
# <a href="https://colab.research.google.com/github/arrowstoflight/AI/blob/master/HW_2/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dustin White
#
# CAP4630 - Artificial Intelligence
#
# Professor Wocjan
#
# 5 February 2020
#
# Homework 2

# %% [markdown]
# # Problem 1

# %% [markdown]
# Find three simple bivariate functions f1, f2, and f3 and three points p1, p2, p3 such that
#
# * p1 is a minimum of f1
# * p2 is a maximum of f2
# * p3 is neither a minimum nor maximum of f3, but the gradient of f3 at p3 is the zero vector.
#
# Use (a) three-dimensional plots as in three_dimensional_plotting.ipynb and (b) density plots and (c) contour plots as in density_and_contour_plots.ipynb. Indicate clearly the points p1, p2, and p3 in all plots.

# %% [markdown]
# ## Function 1

# %%
# 3D Plot: F(1) = x^2 + y^2
# p1 is a minimum of f1
# Reference: https://colab.research.google.com/drive/1pcvtvK6jITbp1Sf2nD2uEaDGpwUOA3IL#scrollTo=mKXV05AMvlKh
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return (x ** 2) + (y ** 2)

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# p1
ax.scatter([0], [0], [0], color="blue", s=50, label="Min")
ax.text(0, 0, 6,'Min', color = 'red')

ax.view_init(50, 20)

# %%
# Density Plot
# Reference: https://python-graph-gallery.com/85-density-plot-with-matplotlib/
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import kde
 
def f(x, y):
  return (x ** 2) + (y ** 2)

# create data
x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
z = f(X, Y)
 
# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
nbins=300
#k = kde.gaussian_kde([x,y])
xi, yi = np.mgrid[x.min():x.max():nbins*1j, y.min():y.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))
 
# Make the plot
plt.pcolormesh(xi, yi, zi.reshape(xi.shape))
#plt.show()
 
# Add color bar
plt.pcolormesh(xi, yi, zi.reshape(xi.shape), cmap=plt.cm.Reds_r)
plt.colorbar()
plt.show()

# %%
# Plot: F(1) = x^2 + y^2
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

def f(x, y):
    return (x ** 2) + (y ** 2)

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

#plot p1 - Local Min
plt.plot(0,0,'or', c= 'blue')
plt.text(0,0.25,"Minimum", c = 'white')

plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# ## Function 2

# %%
# 3D Plot: F(1) = x^2 + y^2
# p1 is a minimum of f1
# Reference: https://colab.research.google.com/drive/1pcvtvK6jITbp1Sf2nD2uEaDGpwUOA3IL#scrollTo=mKXV05AMvlKh
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return -((x ** 2) + (y ** 2))

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# p1
ax.scatter([0], [0], [0], color="blue", s=50, label="Min")
ax.text(0, 0, 10,'Max', color = 'red')

ax.view_init(50, 20)

# %%
# Plot: F(1) = x^2 + y^2
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

def f(x, y):
    return -((x ** 2) + (y ** 2))

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

#plot p1 - Local Min
plt.plot(0,0,'or', c= 'blue')
plt.text(0,0.25,"Maximum", c = 'white')

plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# ## Function 3

# %%
# 3D-Plot
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x*y

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# p1
ax.scatter([0], [0], [0], color="blue", s=50, label="Min")
ax.text(2, 2, -5,'p 3', color = 'red')

ax.view_init(20, 70)

# %%
# Contour Plot
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

def f(x, y):
    return x*y

x = np.linspace(-5, 5, 25)
y = np.linspace(-5, 5, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

#plot p1 - Local Min
plt.plot(0,0,'or', c= 'blue')
plt.text(0,0.25,"p 3", c = 'black')

plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# # Problem 2

# %% [markdown]
# Extend the code for mini-batch gradient descent in the notebook linear_regression_gradient_descent.ipynb to the case n=2, that is, the model parameters are the two weights w1 and w2 and the bias term b. (You can remove the code for batch-gradient descent and stochastic gradient descent.) Make sure that your code is vectorized.
#
# To solve this problem, you have to create data points that approximately lie on a 2D plane, display these points, and display the predictions of your model after tuning the parameters with gradient descent.

# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# generate m random pairs (x, y)
m = 100
X = 2 * np.random.rand(m, 1)
y = 4 + 3 * X + np.random.rand(m, 1)
X_b = np.column_stack([np.ones((m, 1)), X])

# number of epochs
epochs = 20
# learning rate
lr = 0.01
# fix initial random weight for gradient descent (batch gradient descent)
np.random.seed(42)
initial_weight = np.random.randn(2, 1) 

weight = initial_weight
weight_path_bgd = []
weight_path_sgd = []
weight_path_mgd = []
batch_size = 4

weight_path_mgd.append(weight)
for epoch in range(epochs):
    shuffled_indices = np.random.permutation(m)
    X_b_shuffled = X_b[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(0, m, batch_size):
        xi = X_b_shuffled[i:i+batch_size]
        yi = y_shuffled[i:i+batch_size]
        gradient = 1 / batch_size * xi.T.dot(xi.dot(weight) - yi)
        weight = weight - lr * gradient
        weight_path_mgd.append(weight)

weight_path_mgd[-1]
weight_path_bgd = np.array(weight_path_bgd)
weight_path_sgd = np.array(weight_path_sgd)
weight_path_mgd = np.array(weight_path_mgd)

plt.figure(figsize=(12,12))
plt.plot(weight_path_sgd[:, 0], weight_path_sgd[:, 1], "r-s", linewidth=1, label="stochastic")
plt.plot(weight_path_mgd[:, 0], weight_path_mgd[:, 1], "g-s", linewidth=2, label="mini-batch")
plt.plot(weight_path_bgd[:, 0], weight_path_bgd[:, 1], "b-s", linewidth=3, label="batch")
plt.legend(loc="upper left", fontsize=16)
plt.xlabel(r"$w_0$", fontsize=20)
plt.ylabel(r"$w_1$   ", fontsize=20, rotation=0)
plt.axis([-1, 5, -1, 4])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-110-37d23eda5687> in <module>()
#      45
#      46 plt.figure(figsize=(12,12))
# ---> 47 plt.plot(weight_path_sgd[:, 0], weight_path_sgd[:, 1], "r-s", linewidth=1, label="stochastic")
#      48 plt.plot(weight_path_mgd[:, 0], weight_path_mgd[:, 1], "g-s", linewidth=2, label="mini-batch")
#      49 plt.plot(weight_path_bgd[:, 0], weight_path_bgd[:, 1], "b-s", linewidth=3, label="batch")
#
# IndexError: too many indices for array

# %% [markdown]
# #Problem 3

# %% [markdown]
# What does an average MNIST digit look like? For each i=0,1,...,9, compute the average of digit i and display it. More precisely, you have add all the images of the digit i together and divide it by the number of times the digit i occurs in the data set.
#
# Use tf.keras.datasets to load the MNIST digits dataset.
#
# References:
#
# https://www.python-course.eu/neural_network_mnist.php
#
# https://www.tensorflow.org/tutorials/keras/classification

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

digits= []
for i in range(0,10):
  digits.append(np.where(train_labels == i))
  
for i in range(0,10):
  numArray = np.array(np.mean(train_images[digits[i][0]], axis=(0)), dtype=np.int16)
  output = Image.fromarray(numArray)
  plt.figure(figsize=(4, 4))
  plt.imshow(output)
  plt.show()
